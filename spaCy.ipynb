# %%
import spacy
from spacy import displacy

# %%
# Importieren der Deutschen und Englischen Sprachannotationen
# Das sind jeweils die kleinsten Versionen ~20-30mb
# große Versionen reichen bis an die 800mb

nlp = spacy.load("en_core_web_sm")
nlp_de = spacy.load("de_core_news_sm")

# %%
text = ("Hello there, my name is John. I am a huge Star Wars fan and also like Ferrari.")

doc = nlp(text)

# %%
print('-----------------------------------')
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# -----------------------------------
# Hello INTJ intj
# there ADV advmod
# , PUNCT punct
# my DET poss
# name NOUN nsubj
# is AUX ROOT
# John PROPN attr
# . PUNCT punct
# I PRON nsubj
# am AUX ROOT
# a DET det
# huge ADJ amod
# Star PROPN compound
# Wars PROPN compound
# fan NOUN attr
# and CCONJ cc
# also ADV advmod
# like SCONJ conj
# Ferrari PROPN pobj
# . PUNCT punct

# %%
# Nun folgt ein deutscher Text

text_de = "Dies ist ein deutscher Text. Ich kaufe immer bei Apple ein und mache viel Kohle."

doc_de = nlp_de(text_de)

# %%
# spaCy kann auch Eigennamen (named entities) sehr leicht erkennen
for ent in doc_de.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# deutscher 13 22 MISC
# Apple 49 54 ORG

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# John 24 28 PERSON
# Star Wars 42 51 WORK_OF_ART
# Ferrari 70 77 ORG

# %% [markdown]
# ## displaCy kann die Dependenzstrukturen dann ganz leicht sichtbar machen:

# %%
displacy.render(doc, style="dep", jupyter=True, options={'distance': 140})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fe022836fc0e44c4b21b8dc3e1b40d2e-0" class="displacy" width="890" height="277.0" direction="ltr" style="max-width: none; height: 277.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">there,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">my</tspan>
# ...

# %%
#Damit wir einzelne Saetze rendern koennen, machen wir aus dem Dokument eine Liste:
sentences = list(doc.sents)
displacy.render(sentences[0], style="dep", jupyter=True, options={'distance': 140})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="172f9b5c174c49d7831796c34d43e02e-0" class="displacy" width="890" height="277.0" direction="ltr" style="max-width: none; height: 277.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">there,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="187.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">my</tspan>
# ...

# %%
displacy.render(sentences[1], style="dep", jupyter=True, options={'distance': 140})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9df5637e1620422fa35e108e6f642425-0" class="displacy" width="1590" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">a</tspan>
# ...
